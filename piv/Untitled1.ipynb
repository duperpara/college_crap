# %%
import identification
import matplotlib.pyplot as plt
import pprint
import control
import scipy
import numpy as np

# %%
data = identification.run()
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#       ...
# 894    200
# 895    200
# 896    200
# 897    198
# 898    198
# Name: Output, Length: 899, dtype: int64
# {'s_20_to_30': {'start_idx': 232, 'end_idx': 359, 'data': 0       0
# 1       3
# 2       4
# 3       6
# 4       8
#        ..
# 122    33
# 123    30
# 124    30
# 125    30
# 126    29
# Name: Output, Length: 127, dtype: int64, 'delta_pwm': 10, 'delta_t': 127, 'delta_h': 34, 'k': 3.4, 'yt1_SM': 9.622000000000002, 't1_SM': 8, 'yt2_SM': 21.488, 't2_SM': 32, 'tau_SM': 36.0, 'teta_SM': 0, 'tf': TransferFunction(array([3.4]), array([36.,  1.]))}, 's_30_to_40': {'start_idx': 358, 'end_idx': 443, 'data': 0      0
# 1      2
# 2      8
# 3      4
# 4      9
#       ..
# 80    37
# 81    41
# 82    37
# 83    40
# 84    38
# Name: Output, Length: 85, dtype: int64, 'delta_pwm': 10, 'delta_t': 85, 'delta_h': 47, 'k': 4.7, 'yt1_SM': 13.301000000000002, 't1_SM': 10, 'yt2_SM': 29.704, 't2_SM': 31, 'tau_SM': 31.5, 'teta_SM': 0, 'tf': TransferFunction(array([4.7]), array([31.5,  1. ]))}, 's_40_to_50': {'start_idx': 442, 'end_idx': 597, 'data': 0       3
# 1       5
# 2       0
# 3       7
# 4       6
#        ..
# 150    46
# 151    46
# 152    46
# 153    45
# 154    45
# Name: Output, Length: 155, dtype: int64, 'delta_pwm': 10, 'delta_t': 155, 'delta_h': 44, 'k': 4.4, 'yt1_SM': 13.301000000000002, 't1_SM': 17, 'yt2_SM': 29.704, 't2_SM': 34, 'tau_SM': 25.5, 'teta_SM': 8.5, 'tf': TransferFunction(array([4.4]), array([25.5,  1. ]))}, 's_50_to_60': {'start_idx': 596, 'end_idx': 899, 'data': 0       0
# 1       1
# 2       7
# 3       6
# 4       7
#        ..
# 298    60
# 299    60
# 300    60
# 301    58
# 302    58
# Name: Output, Length: 303, dtype: int64, 'delta_pwm': 10, 'delta_t': 303, 'delta_h': 61, 'k': 6.1, 'yt1_SM': 17.263, 't1_SM': 21, 'yt2_SM': 38.552, 't2_SM': 64, 'tau_SM': 64.5, 'teta_SM': 0, 'tf': TransferFunction(array([6.1]), array([64.5,  1. ]))}}
# s_20_to_30
# {'delta_h': 34,
#  'delta_pwm': 10,
#  'delta_t': 127,
#  'end_idx': 359,
#  'k': 3.4,
#  'start_idx': 232,
#  't1_SM': 8,
#  't2_SM': 32,
#  'tau_SM': 36.0,
#  'teta_SM': 0,
#  'tf': TransferFunction(array([3.4]), array([36.,  1.])),
#  'yt1_SM': 9.622000000000002,
#  'yt2_SM': 21.488}
# s_30_to_40
# {'delta_h': 47,
#  'delta_pwm': 10,
#  'delta_t': 85,
#  'end_idx': 443,
#  'k': 4.7,
#  'start_idx': 358,
#  't1_SM': 10,
#  't2_SM': 31,
#  'tau_SM': 31.5,
#  'teta_SM': 0,
#  'tf': TransferFunction(array([4.7]), array([31.5,  1. ])),
#  'yt1_SM': 13.301000000000002,
#  'yt2_SM': 29.704}
# s_40_to_50
# {'delta_h': 44,
#  'delta_pwm': 10,
#  'delta_t': 155,
#  'end_idx': 597,
#  'k': 4.4,
#  'start_idx': 442,
#  't1_SM': 17,
#  't2_SM': 34,
#  'tau_SM': 25.5,
#  'teta_SM': 8.5,
#  'tf': TransferFunction(array([4.4]), array([25.5,  1. ])),
#  'yt1_SM': 13.301000000000002,
#  'yt2_SM': 29.704}
# s_50_to_60
# {'delta_h': 61,
#  'delta_pwm': 10,
#  'delta_t': 303,
#  'end_idx': 899,
#  'k': 6.1,
#  'start_idx': 596,
#  't1_SM': 21,
#  't2_SM': 64,
#  'tau_SM': 64.5,
#  'teta_SM': 0,
#  'tf': TransferFunction(array([6.1]), array([64.5,  1. ])),
#  'yt1_SM': 17.263,
#  'yt2_SM': 38.552}

# %%
for key, value in data.items():
    print(key)
    value.get('data').plot()
    # plt.plot(value.get('data').index, control.forced_response(value.get('tf'), T=value.get('data').index, U=value.get('delta_pwm')))
    plt.plot(
        *control.forced_response(
            value.get('tf'), 
            T=np.linspace(0, value.get('delta_t'), value.get('delta_t')+1), 
            U=value.get('delta_pwm'), 
        ), 
        'red'
    )
    
    plt.show()
    display(value.get('tf'))
    pprint.pprint({v_key: v_value for v_key, v_value in value.items() if (v_key != 'data') and (v_key != 'tf')})
    print('\n')
# Out:
# s_20_to_30
# TransferFunction(array([3.4]), array([36.,  1.]))
# {'delta_h': 34,
#  'delta_pwm': 10,
#  'delta_t': 127,
#  'end_idx': 359,
#  'k': 3.4,
#  'start_idx': 232,
#  't1_SM': 8,
#  't2_SM': 32,
#  'tau_SM': 36.0,
#  'teta_SM': 0,
#  'yt1_SM': 9.622000000000002,
#  'yt2_SM': 21.488}
#
#
# s_30_to_40
# TransferFunction(array([4.7]), array([31.5,  1. ]))
# {'delta_h': 47,
#  'delta_pwm': 10,
#  'delta_t': 85,
#  'end_idx': 443,
#  'k': 4.7,
#  'start_idx': 358,
#  't1_SM': 10,
#  't2_SM': 31,
#  'tau_SM': 31.5,
#  'teta_SM': 0,
#  'yt1_SM': 13.301000000000002,
#  'yt2_SM': 29.704}
#
#
# s_40_to_50
# TransferFunction(array([4.4]), array([25.5,  1. ]))
# {'delta_h': 44,
#  'delta_pwm': 10,
#  'delta_t': 155,
#  'end_idx': 597,
#  'k': 4.4,
#  'start_idx': 442,
#  't1_SM': 17,
#  't2_SM': 34,
#  'tau_SM': 25.5,
#  'teta_SM': 8.5,
#  'yt1_SM': 13.301000000000002,
#  'yt2_SM': 29.704}
#
#
# s_50_to_60
# TransferFunction(array([6.1]), array([64.5,  1. ]))
# {'delta_h': 61,
#  'delta_pwm': 10,
#  'delta_t': 303,
#  'end_idx': 899,
#  'k': 6.1,
#  'start_idx': 596,
#  't1_SM': 21,
#  't2_SM': 64,
#  'tau_SM': 64.5,
#  'teta_SM': 0,
#  'yt1_SM': 17.263,
#  'yt2_SM': 38.552}

# %%
key, value = 's_50_to_60', data.get('s_50_to_60')
print(key)
# plt.plot(value.get('data').index, control.forced_response(value.get('tf'), T=value.get('data').index, U=value.get('delta_pwm')))
kp = 2.373
ki = 2.53
plt.plot(
    *control.step_response(
        control.tf([6.1*kp, 6.1*ki], [64.5, (6.1*kp + 1), 6.1*ki])
)
)

kp = 5.0754
ki = 4.9114
plt.plot(
    *control.step_response(
        control.tf([6.1*kp, 6.1*ki], [64.5, (6.1*kp + 1), 6.1*ki])),
    color='green'
)
plt.show()

kp = 2.5
ki = 5.07
plt.plot(
    *control.step_response(
        control.tf([6.1*kp, 6.1*ki], [64.5, (6.1*kp + 1), 6.1*ki])),
    color='orange'
)
plt.show()


print('\n')
# Out:
# s_50_to_60

# %%
key, value = 's_50_to_60', data.get('s_50_to_60')
print(key)
# plt.plot(value.get('data').index, control.forced_response(value.get('tf'), T=value.get('data').index, U=value.get('delta_pwm')))
kp = 2.373
ki = 2.53
plt.plot(
        *scipy.signal.step(scipy.signal.lti([6.1*kp, 6.1*ki], [64.5, (6.1*kp + 1), 6.1*ki]))
)
plt.grid()
plt.show()
display(value.get('tf'))
print('\n')
# Out:
# s_50_to_60
# TransferFunction(array([6.1]), array([64.5,  1. ]))

# %%
key, value = 's_50_to_60', data.get('s_50_to_60')
print(key)
# plt.plot(value.get('data').index, control.forced_response(value.get('tf'), T=value.get('data').index, U=value.get('delta_pwm')))
#for kp, ki in zip(np.linspace(0,10, 11), np.linspace(0,10, 101)):
kp = 2.373
ki = 2.53

grf = control.step_response(
        control.tf([6.1*kp, 6.1*ki], [64.5, (6.1*kp + 1), 6.1*ki]))

S0 = (max(grf[1])-1)*100
Ereg = (grf[1][-1]-1)*100

ta = None
for idx, val in zip(reversed(grf[0]), reversed(grf[1])):
    if (val-1)*100 > 5:
        ta = idx
        break

print(f"{S0=}%, {Ereg=}%, {ta=}s")
plt.plot(
    *grf
)



print('\n')
# Out:
# s_50_to_60
# S0=50.42299404282671%, Ereg=0.07483886927044381%, ta=20.892624078562484s

# %%
from modeling import flow_rate_equations, evaluate_tf_constants

flw_eqs = flow_rate_equations()

for name, h in {"s_20_to_30": 0.065, "s_30_to_40": 0.0107, "s_40_to_50": 0.0142, "s_50_to_60": 0.0201}.items():

    theo_tf_symp = evaluate_tf_constants(flw_eqs, h0=h, a=4.037088288e-5, A=0.009506, K=0.0009027*12)
    theo_tf_K = float(theo_tf_symp.args[0])
    theo_tf_tau = float(theo_tf_symp.args[1].base.args[1].args[0])
    theo_tf = control.tf(theo_tf_K, [theo_tf_tau, 1])
    print(name, ':')
    plt.plot(*control.step_response(theo_tf), color='red')
    plt.plot(*control.step_response(data.get(name).get('tf')), color='blue')
    plt.show()
    print("theoretical modeling (red):")
    display(theo_tf)
    print("empiric modeling (blue):")
    display(data.get(name).get('tf'))
# Out:
# dhdt_flow: d*h/dt = (Ve - Vs)/A
# in_flow: Ve = K*U
# out_flow1: Vs = a*v
# out_flow2: Vs = sqrt(2)*a*sqrt(g)*sqrt(h)
# out_flow3: Vs = sqrt(2)*a*sqrt(g)*sqrt(pf/(g*ro))
# dhdt_flow_detailed: d*h/dt = (K*U - sqrt(2)*a*sqrt(g)*sqrt(h))/A
# h_subs: h = Delta_h + h0
# U_subs: U = Delta_U + U0
# delta_flow_detailed: d*(Delta_h + h0)/dt = (K*(Delta_U + U0) - sqrt(2)*a*sqrt(g)*sqrt(Delta_h + h0))/A
# equilibrium: K*U0 = sqrt(2)*a*sqrt(g*h0)
# linearize: A*Delta_h*d/dt = Delta_U*K - sqrt(2)*Delta_h*a*sqrt(g)/(2*sqrt(h0)) + K*U0 - sqrt(2)*a*sqrt(g*h0)
# linearize_equilibrium: A*Delta_h*d/dt = Delta_U*K - sqrt(2)*Delta_h*a*sqrt(g)/(2*sqrt(h0))
# alpha_subs: alpha = sqrt(2)*a*sqrt(g)/(2*sqrt(h0))
# linearize_equilibrium_alpha_subs: A*Delta_h*d/dt = Delta_U*K - Delta_h*alpha
# laplace_transform: A*Delta_h*s = Delta_U*K - Delta_h*alpha
# tau_subs: tau = A/alpha
# Ke_subs: Ke = K/alpha
# laplace_tau_Ke_subs_simplify: Delta_h = Delta_U*Ke/(s*tau + 1)
# tf: Delta_h/Delta_U = Ke/(s*tau + 1)
# s_20_to_30 :
# theoretical modeling (red):
# TransferFunction(array([30.89457128]), array([27.11160912,  1.        ]))
# empiric modeling (blue):
# TransferFunction(array([3.4]), array([36.,  1.]))
# s_30_to_40 :
# theoretical modeling (red):
# TransferFunction(array([12.53479927]), array([10.99994478,  1.        ]))
# empiric modeling (blue):
# TransferFunction(array([4.7]), array([31.5,  1. ]))
# s_40_to_50 :
# theoretical modeling (red):
# TransferFunction(array([14.44008225]), array([12.67193067,  1.        ]))
# empiric modeling (blue):
# TransferFunction(array([4.4]), array([25.5,  1. ]))
# s_50_to_60 :
# theoretical modeling (red):
# TransferFunction(array([17.1800144]), array([15.07636506,  1.        ]))
# empiric modeling (blue):
# TransferFunction(array([6.1]), array([64.5,  1. ]))
