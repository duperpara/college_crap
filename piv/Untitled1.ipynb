# %%
import identification
import matplotlib.pyplot as plt
import pprint
import control
import scipy
import numpy as np

# %%
data = identification.run()
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#       ...
# 894    200
# 895    200
# 896    200
# 897    198
# 898    198
# Name: Output, Length: 899, dtype: int64
# {'s_20_to_30': {'start_idx': 232, 'end_idx': 359, 'data': 0       0
# 1       3
# 2       4
# 3       6
# 4       8
#        ..
# 122    33
# 123    30
# 124    30
# 125    30
# 126    29
# Name: Output, Length: 127, dtype: int64, 'delta_pwm': 10, 'delta_t': 127, 'delta_h': 34, 'k': 3.4, 'yt1_SM': 9.622000000000002, 't1_SM': 8, 'yt2_SM': 21.488, 't2_SM': 32, 'tau_SM': 36.0, 'teta_SM': 0, 'Kp': 2.6470588235294117, 'tf': TransferFunction(array([3.4]), array([36.,  1.]))}, 's_30_to_40': {'start_idx': 358, 'end_idx': 443, 'data': 0      0
# 1      2
# 2      8
# 3      4
# 4      9
#       ..
# 80    37
# 81    41
# 82    37
# 83    40
# 84    38
# Name: Output, Length: 85, dtype: int64, 'delta_pwm': 10, 'delta_t': 85, 'delta_h': 47, 'k': 4.7, 'yt1_SM': 13.301000000000002, 't1_SM': 10, 'yt2_SM': 29.704, 't2_SM': 31, 'tau_SM': 31.5, 'teta_SM': 0, 'Kp': 1.9148936170212767, 'tf': TransferFunction(array([4.7]), array([31.5,  1. ]))}, 's_40_to_50': {'start_idx': 442, 'end_idx': 597, 'data': 0       3
# 1       5
# 2       0
# 3       7
# 4       6
#        ..
# 150    46
# 151    46
# 152    46
# 153    45
# 154    45
# Name: Output, Length: 155, dtype: int64, 'delta_pwm': 10, 'delta_t': 155, 'delta_h': 44, 'k': 4.4, 'yt1_SM': 13.301000000000002, 't1_SM': 17, 'yt2_SM': 29.704, 't2_SM': 34, 'tau_SM': 25.5, 'teta_SM': 8.5, 'Kp': 2.0454545454545454, 'tf': TransferFunction(array([4.4]), array([25.5,  1. ]))}, 's_50_to_60': {'start_idx': 596, 'end_idx': 899, 'data': 0       0
# 1       1
# 2       7
# 3       6
# 4       7
#        ..
# 298    60
# 299    60
# 300    60
# 301    58
# 302    58
# Name: Output, Length: 303, dtype: int64, 'delta_pwm': 10, 'delta_t': 303, 'delta_h': 61, 'k': 6.1, 'yt1_SM': 17.263, 't1_SM': 21, 'yt2_SM': 38.552, 't2_SM': 64, 'tau_SM': 64.5, 'teta_SM': 0, 'Kp': 1.4754098360655736, 'tf': TransferFunction(array([6.1]), array([64.5,  1. ]))}}
# s_20_to_30
# {'Kp': 2.6470588235294117,
#  'delta_h': 34,
#  'delta_pwm': 10,
#  'delta_t': 127,
#  'end_idx': 359,
#  'k': 3.4,
#  'start_idx': 232,
#  't1_SM': 8,
#  't2_SM': 32,
#  'tau_SM': 36.0,
#  'teta_SM': 0,
#  'tf': TransferFunction(array([3.4]), array([36.,  1.])),
#  'yt1_SM': 9.622000000000002,
#  'yt2_SM': 21.488}
# s_30_to_40
# {'Kp': 1.9148936170212767,
#  'delta_h': 47,
#  'delta_pwm': 10,
#  'delta_t': 85,
#  'end_idx': 443,
#  'k': 4.7,
#  'start_idx': 358,
#  't1_SM': 10,
#  't2_SM': 31,
#  'tau_SM': 31.5,
#  'teta_SM': 0,
#  'tf': TransferFunction(array([4.7]), array([31.5,  1. ])),
#  'yt1_SM': 13.301000000000002,
#  'yt2_SM': 29.704}
# s_40_to_50
# {'Kp': 2.0454545454545454,
#  'delta_h': 44,
#  'delta_pwm': 10,
#  'delta_t': 155,
#  'end_idx': 597,
#  'k': 4.4,
#  'start_idx': 442,
#  't1_SM': 17,
#  't2_SM': 34,
#  'tau_SM': 25.5,
#  'teta_SM': 8.5,
#  'tf': TransferFunction(array([4.4]), array([25.5,  1. ])),
#  'yt1_SM': 13.301000000000002,
#  'yt2_SM': 29.704}
# s_50_to_60
# {'Kp': 1.4754098360655736,
#  'delta_h': 61,
#  'delta_pwm': 10,
#  'delta_t': 303,
#  'end_idx': 899,
#  'k': 6.1,
#  'start_idx': 596,
#  't1_SM': 21,
#  't2_SM': 64,
#  'tau_SM': 64.5,
#  'teta_SM': 0,
#  'tf': TransferFunction(array([6.1]), array([64.5,  1. ])),
#  'yt1_SM': 17.263,
#  'yt2_SM': 38.552}

# %%
for key, value in data.items():
    print(key)
    value.get('data').plot()
    # plt.plot(value.get('data').index, control.forced_response(value.get('tf'), T=value.get('data').index, U=value.get('delta_pwm')))
    plt.plot(
        *control.forced_response(
            value.get('tf'), 
            T=np.linspace(0, value.get('delta_t'), value.get('delta_t')+1), 
            U=value.get('delta_pwm'), 
        ), 
        'red'
    )
    
    plt.show()
    display(value.get('tf'))
    pprint.pprint({v_key: v_value for v_key, v_value in value.items() if (v_key != 'data') and (v_key != 'tf')})
    print('\n')
# Out:
# s_20_to_30
# TransferFunction(array([3.4]), array([36.,  1.]))
# {'Kp': 2.6470588235294117,
#  'delta_h': 34,
#  'delta_pwm': 10,
#  'delta_t': 127,
#  'end_idx': 359,
#  'k': 3.4,
#  'start_idx': 232,
#  't1_SM': 8,
#  't2_SM': 32,
#  'tau_SM': 36.0,
#  'teta_SM': 0,
#  'yt1_SM': 9.622000000000002,
#  'yt2_SM': 21.488}
#
#
# s_30_to_40
# TransferFunction(array([4.7]), array([31.5,  1. ]))
# {'Kp': 1.9148936170212767,
#  'delta_h': 47,
#  'delta_pwm': 10,
#  'delta_t': 85,
#  'end_idx': 443,
#  'k': 4.7,
#  'start_idx': 358,
#  't1_SM': 10,
#  't2_SM': 31,
#  'tau_SM': 31.5,
#  'teta_SM': 0,
#  'yt1_SM': 13.301000000000002,
#  'yt2_SM': 29.704}
#
#
# s_40_to_50
# TransferFunction(array([4.4]), array([25.5,  1. ]))
# {'Kp': 2.0454545454545454,
#  'delta_h': 44,
#  'delta_pwm': 10,
#  'delta_t': 155,
#  'end_idx': 597,
#  'k': 4.4,
#  'start_idx': 442,
#  't1_SM': 17,
#  't2_SM': 34,
#  'tau_SM': 25.5,
#  'teta_SM': 8.5,
#  'yt1_SM': 13.301000000000002,
#  'yt2_SM': 29.704}
#
#
# s_50_to_60
# TransferFunction(array([6.1]), array([64.5,  1. ]))
# {'Kp': 1.4754098360655736,
#  'delta_h': 61,
#  'delta_pwm': 10,
#  'delta_t': 303,
#  'end_idx': 899,
#  'k': 6.1,
#  'start_idx': 596,
#  't1_SM': 21,
#  't2_SM': 64,
#  'tau_SM': 64.5,
#  'teta_SM': 0,
#  'yt1_SM': 17.263,
#  'yt2_SM': 38.552}

# %%
key, value = 's_50_to_60', data.get('s_50_to_60')
print(key)
# plt.plot(value.get('data').index, control.forced_response(value.get('tf'), T=value.get('data').index, U=value.get('delta_pwm')))
kp = 2.373
ki = 2.53
plt.plot(
    *control.step_response(
        control.tf([6.1*kp, 6.1*ki], [64.5, (6.1*kp + 1), 6.1*ki])
)
)

kp = 5.0754
ki = 4.9114
plt.plot(
    *control.step_response(
        control.tf([6.1*kp, 6.1*ki], [64.5, (6.1*kp + 1), 6.1*ki])),
    color='green'
)
plt.show()

kp = 2.5
ki = 5.07
plt.plot(
    *control.step_response(
        control.tf([6.1*kp, 6.1*ki], [64.5, (6.1*kp + 1), 6.1*ki])),
    color='orange'
)
plt.show()


print('\n')
# Out:
# s_50_to_60

# %%
key, value = 's_50_to_60', data.get('s_50_to_60')
print(key)
# plt.plot(value.get('data').index, control.forced_response(value.get('tf'), T=value.get('data').index, U=value.get('delta_pwm')))
kp = 2.373
ki = 2.53
plt.plot(
        *scipy.signal.step(scipy.signal.lti([6.1*kp, 6.1*ki], [64.5, (6.1*kp + 1), 6.1*ki]))
)
plt.grid()
plt.show()
display(value.get('tf'))
print('\n')

# %%
key, value = 's_50_to_60', data.get('s_50_to_60')
print(key)
# plt.plot(value.get('data').index, control.forced_response(value.get('tf'), T=value.get('data').index, U=value.get('delta_pwm')))
#for kp, ki in zip(np.linspace(0,10, 11), np.linspace(0,10, 101)):
kp = 2.373
ki = 2.53

grf = control.step_response(
        control.tf([6.1*kp, 6.1*ki], [64.5, (6.1*kp + 1), 6.1*ki]))

S0 = (max(grf[1])-1)*100
Ereg = (grf[1][-1]-1)*100

ta = None
for idx, val in zip(reversed(grf[0]), reversed(grf[1])):
    if (val-1)*100 > 5:
        ta = idx
        break

print(f"{S0=}%, {Ereg=}%, {ta=}s")
plt.plot(
    *grf
)



print('\n')
# Out:
# s_50_to_60
# S0=50.42299404282671%, Ereg=0.07483886927044381%, ta=20.892624078562484s
